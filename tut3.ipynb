# %% [markdown]
# <a href="https://colab.research.google.com/github/Idhant-Mehta/tutorial-sheets/blob/main/tut3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Difference Between a Given Number and 17

def diff_with_17(n):
    if n > 17:
        return 2 * abs(n - 17)
    else:
        return 17 - n

print(diff_with_17(22))  # Output: 10
print(diff_with_17(14))  # Output: 3
# 2. Test Whether a Number is Within 100 to 1000 or 2000
def test_range(n):
    if 100 <= n <= 1000 or n == 2000:
        return True
    else:
        return False

print(test_range(500))   # Output: True
print(test_range(1500))  # Output: False
print(test_range(2000))  # Output: True
# 3. Reverse a String

def reverse_string(s):
    return s[::-1]

print(reverse_string("hello"))  # Output: "olleh"
# 4. Count the Number of Upper and Lower Case Letters in a String

def count_upper_lower(s):
    upper_count = 0
    lower_count = 0
    for char in s:
        if char.isupper():
            upper_count += 1
        elif char.islower():
            lower_count += 1
    print("Upper case letters:", upper_count)
    print("Lower case letters:", lower_count)

count_upper_lower("Hello World")

# 5. Return a List with Distinct Elements

def distinct_elements(lst):
    return list(set(lst))

print(distinct_elements([1, 2, 2, 3, 4, 4, 5]))  # Output: [1, 2, 3, 4, 5]

# 6. Print Even Numbers from a Given List
def even_numbers(lst):
    return [num for num in lst if num % 2 == 0]

sample_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]

print(even_numbers(sample_list))  # Output: [2, 4, 6, 8]
# 7. Access a Function Inside a Function

def outer_function(text):
    def inner_function():
        print(text)
    inner_function()
outer_function("Hello from inner function!")

# 8. Function student() with Function Attributes

def student(name, age, course):
    student.name = name
    student.age = age
    student.course = course
    return student

# Function attributes
student("Alice", 20, "Math")
print("Name:", student.name)
print("Age:", student.age)
print("Course:", student.course)
# 9. Python Class Student with Display Method
class Student:
    def __init__(self, student_id, student_name):
        self.student_id = student_id
        self.student_name = student_name
        self.student_class = None

    def display(self):
        print(f"ID: {self.student_id}")
        print(f"Name: {self.student_name}")
        print(f"Class: {self.student_class}")

student1 = Student(1, "John")
student1.student_class = "12th Grade"
student1.display()
# 10. Python Class with Two Instances
class Student:
    def __init__(self, student_id, student_name):
        self.student_id = student_id
        self.student_name = student_name

student1 = Student(1, "Alice")
student2 = Student(2, "Bob")

print(f"Student 1: ID = {student1.student_id}, Name = {student1.student_name}")
print(f"Student 2: ID = {student2.student_id}, Name = {student2.student_name}")


# 11. Python Class `Circle` to Compute Area and Perimeter
import math
class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

    def perimeter(self):
        return 2 * math.pi * self.radius

circle1 = Circle(5)
print(f"Area: {circle1.area()}")
print(f"Perimeter: {circle1.perimeter()}")


# 12. Python Class to Get and Print String in Upper Case
class StringManipulator:
    def __init__(self):
        self.string = ""

    def get_string(self):
        self.string = input("Enter a string: ")

    def print_string(self):
        print(self.string.upper())

string_manipulator = StringManipulator()
string_manipulator.get_string()
string_manipulator.print_string()
